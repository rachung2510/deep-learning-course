# %% [markdown]
# <a href="https://colab.research.google.com/github/MatchLab-Imperial/deep-learning-course/blob/master/02_CNN_Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Convolutional Neural Networks
#
# This tutorial addresses the basic concepts regarding Convolutional Neural Networks and their implementation using the Keras framework.
# Convolutional Neural Networks (CNNs) are a class of feed-forward artificial neural architecture. They are applied to analyse visual 2D imagery, meaning that we can feed images directly into a CNN without the need to flatten them into a 1D vector as done in the previous tutorial.
# CNNs have revolutionised the field of computer vision in the last decade. In 2012 Alex Krizhevsky introduced the AlexNet architecture to win the ImageNet Challenge (one of the most important competitions on image classification within the Computer Vision community), by reducing the top-5 error more than 10 percentage points, which was an incredible improvement at that time. As of now, CNNs are used not only on image classification but in many other computer vision tasks.
#
# ![](https://cdn-5f733ed3c1ac190fbc56ef88.closte.com/wp-content/uploads/2017/03/alexnet_small-1.png)
#
# The image above is from [cv-tricks' blog](https://cv-tricks.com/cnn/understand-resnet-alexnet-vgg-inception/) and shows the proposed AlexNet architecture. It is composed of 5 convolutional layers followed by 3 fully connected layers. Nowadays, we can find much deeper and more complex architectures, which outperform AlexNet on the ImageNet Challenge.

# %% [markdown]
# ## CNN Structure
#
# The basic pipeline of common CNNs consists of an image as input and a stack of convolutional layers that extract a feature representation from the input image. The final shape of the image representation is conditioned on the type of problem/task that the architecture is facing. For instance, the output of the last layer in a classification problem is a probability vector. Each dimension of the probability vector represents how likely is that the input image belongs to a specific class. However, the architecture design is up to us, and therefore, we could code a network that outputs a single value for regression problems, or that generates a new image map for semantic segmentation. Now, let's dig in a bit into CNN and introduce some layers that are widely used.

# %% [markdown]
# ### 2D Convolutional Layer
#
# The most common layer in any CNN architecture is the 2D convolutional layer. Convolutional layers are specifically designed to extract features from images or even extract features from previously extracted features. As shown in the following illustration, 2D convolutions apply the same filter to the full image. And therefore, due to its nature, 2D convolutional filters exploit the local information presented in images, making them a powerful tool for image analysis.
#
# ![](https://cdn-images-1.medium.com/max/800/1*Fw-ehcNBR9byHtho-Rxbtw.gif)
#
# Image [source](https://towardsdatascience.com/intuitively-understanding-convolutions-for-deep-learning-1f6f42faee1).
#
# The latest deep learning frameworks have made possible the integration of convolutional layers easily on our architectures with only a single line of code. We will address here how 2D convolutions work since full understanding is needed to comprehend how any CNN operates. The following images and some explanations can be further explored on the original [Irhum Shafkat's blog](https://towardsdatascience.com/intuitively-understanding-convolutions-for-deep-learning-1f6f42faee1) or in the [Neural Networks and Deep Learning](http://neuralnetworksanddeeplearning.com/) book. Both are strongly recommended.
#
# To understand 2D convolutions, we need to define first what a kernel is. Kernels are simply matrices of numbers. The numbers on the kernels are the so-called weights, and the weights on the kernels change as we train the network. Hence, network training aims to optimise the network's parameters (update the kernel weights) such that the cost function is minimised.
#
# The 2D convolution operation takes the network's kernels and "slides" them over the input image (alike to a sliding window) as in the following image from [PyImageSearch](https://www.pyimagesearch.com/2015/03/23/sliding-windows-for-object-detection-with-python-and-opencv/) blog:
#
# ![](https://pyimagesearch.com/wp-content/uploads/2014/10/sliding_window_example.gif)
#
# In each step, the network performs an element-wise multiplication with the elements that are currently on. The results of this elementwise multiplication are added to obtain the output value of the operation. CNNs repeat previous step for all the positions of the sliding window, composing at the end the feature map. This generated feature map can go through another 2D convolutional layer and create more powerful features.
#
# >
#
# ![](https://cdn-images-1.medium.com/max/800/1*Zx-ZMLKab7VOCQTxdZ1OAw.gif)
#
# >
# The previous image shows the 2D convolution operation. Thus, the new feature values are the weighted sum of all the elements in the sliding window after the elementwise multiplication between input and kernel.  The bigger the size of the kernel is, the more feature elements contribute to the final output value. In contrast to fully connected layers, where a new feature value is a weighted sum over **all** input values, as mentioned, 2D convolutions compute features based on local areas. In other words, instead of looking at every input component, they consider only features coming from close locations.
#
# In the above example, the input image on the left has a size of 5x5 and the dimension of the resulting feature map is 3x3, showing that the size of the output maps is not always equal to the input. Hence, the output size can be computed by doing:
#
# $O = W - K + 1$,
#
# where $O$ is the output height/length, $W$ is the input height/length and $K$ is the kernel size. The output size is not only conditioned on the input size but also on the kernel size. Check in the following code cell how the output feature map shape changes as you increase the kernel size. In Keras, we define the layer by using `Conv2D` from `keras.layers` (documentation [here](https://keras.io/layers/convolutional/#conv2d)).

# %%
import numpy as np
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D

# Generate dummy data
input_feature = np.random.random((1, 100, 100, 1))

# input: 100x100 image with 1 channels -> (100, 100, 1) tensor.
# this applies 1 convolution filter of size 3x3 each.
model = Sequential()
model.add(Conv2D(1, (3, 3), input_shape=(100, 100, 1)))

output_feature = model.predict(input_feature)

print('Input size: ({:}, {:})'.format(input_feature.shape[1], input_feature.shape[2]))
print('Output size: ({:}, {:})'.format(output_feature.shape[1], output_feature.shape[2]))
# Out:
# 1/1 [==============================] - 11s 11s/step
# Input size: (100, 100)
# Output size: (98, 98)

# %% [markdown]
# Moreover, the kernel size and the input size are not the only parameters affecting the output size. We are going to introduce two extra elements that change the size of the output map: the padding and the stride.

# %% [markdown]
# ### Adding Padding to Input Features
#
# In some tasks, such as [image translation](https://arxiv.org/pdf/1611.07004.pdf), we need the output size to be equal to the input size. The solution to that is using padding, where extra edges are added to the input features so that the dimension is not reduced after the convolutional layer. Normally those pixels have $0$ value (termed zero-padding), but depending on the application other methods could be used, e.g., reflection or symmetric padding.
#
# ![](https://cdn-images-1.medium.com/max/800/1*1okwhewf5KCtIPaFib4XaA.gif)
#
# If padding is used, the new output size can be computed by doing:
#
# $O = W - K + 2P+ 1$,
#
# where $P$ is the padding value. $P$ must be set in concordance with the kernel size if dimensionality wants to be preserved. Padding can be added to the `Conv2d` layer in Keras by using the padding argument and selecting one of the two settings: `valid`, which is the default value and means no padding; and `same`, which adapts the padding value to have the same output size as input size.

# %%
import numpy as np
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D

# Generate dummy data
input_feature = np.random.random((1, 100, 100, 1))

# input: 100x100 image with 1 channels -> (100, 100, 1) tensor.
# this applies 1 convolution filter of size 3x3 each.
# attribute padding='same' applies zero-padding to the input feature map
model = Sequential()
model.add(Conv2D(1, (3, 3), input_shape=(100, 100, 1), padding='same'))

output_feature = model.predict(input_feature)

print('Input size: ({:}, {:})'.format(input_feature.shape[1], input_feature.shape[2]))
print('Output size: ({:}, {:})'.format(output_feature.shape[1], output_feature.shape[2]))
# Out:
# 1/1 [==============================] - 0s 53ms/step
# Input size: (100, 100)
# Output size: (100, 100)

# %% [markdown]
# ### Using Stride in Convolutional Layers
#
# The stride operation allows the convolutional layers to skip some of the sliding windows explained above. Hence, instead of jumping one pixel apart, we can define the number of skipped elements before computing the weighting sum between the kernel's weights and input features. A stride of 1 means that features will be extracted from all windows a pixel apart, so basically, every single window is computed. A stride of 2 means that we are selecting windows 2 pixels apart, skipping every other window in the process. Strides reduce the number of computations and consequently the size of the output map. In practice, as we go deeper into the CNN, the spatial size of the feature map gets smaller while the number of channels increases. Moreover, we can further reduce the size of the feature map using pooling operations, which we introduce later in this tutorial.
#
# ![](https://cdn-images-1.medium.com/max/800/1*BMngs93_rm2_BpJFH2mS0Q.gif)
#
# If strides are used, the new output size can be computed as:
#
# $O = \dfrac{W - K + 2P}{S}+ 1$,
#
# where $S$ is the stride value. The stride is set in the layer by using the `strides` argument.

# %%
import numpy as np
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D

# Generate dummy data
input_feature = np.random.random((1, 100, 100, 1))

# input: 100x100 image with 1 channels -> (100, 100, 1) tensor.
# this applies 1 convolution filter of size 3x3 each.
# attribute padding='same' applies zero-padding to the input feature map
# attribute strides=2 applies applies stride of 2
model = Sequential()
model.add(Conv2D(1, (3, 3), input_shape=(100, 100, 1), padding='same', strides=2))

output_feature = model.predict(input_feature)

print('Input size: ({:}, {:})'.format(input_feature.shape[1], input_feature.shape[2]))
print('Output size: ({:}, {:})'.format(output_feature.shape[1], output_feature.shape[2]))
# Out:
# 1/1 [==============================] - 0s 61ms/step
# Input size: (100, 100)
# Output size: (50, 50)

# %% [markdown]
# ## Differences Between Kernel and Filters
#
# The examples above take as input a single-channel image and compute a feature map with also one channel. However, when dealing with RGB images or feature maps, the input is no longer a single-channel map but, instead, they can have multiple channels. In the case of an RGB image, for each 2D convolution, we will need to define 3 kernels to interact with each of the image's channel colours. This group of kernels is called a filter. Thus, a filter is a collection of kernels that produces a single output.
#
# As a regular practice when defining Deep Learning models, we increase the number of filters in each convolutional layer as we go deeper into the model. Due to the element-wise multiplication, the number of kernels on each filter must be the same that the number of channels in the input feature map. Keras already deals with the number of kernels inside each filter. Keras keeps track of the input size in each convolutional layer unlike other frameworks (Pytorch or TensorFlow). Hence, in Keras, we must only decide the number of filters (output channels) in each layer.
#
# The next figure shows how the convolution is performed when having three input channels. First, one filter uses its three independent kernels to convolve with the RGB channels of the input image:
#
# ![](https://cdn-images-1.medium.com/max/1000/1*8dx6nxpUh2JqvYWPadTwMQ.gif)
#
# Next, each of the processed feature maps is added together to obtain a single channel:
#
# ![](https://cdn-images-1.medium.com/max/1000/1*CYB2dyR3EhFs1xNLK8ewiA.gif)
#
# Finally, we add the bias term to obtain the feature map. There is a single bias for the full output channel map. This operation is repeated for all the filters inside the convolutional layer.
#
# Now, we show how to use a `Conv2D` layer that takes an input image with 3 channels and generates an output map with 32 channels.

# %%
import numpy as np
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D

# Generate dummy data
input_feature = np.random.random((1, 100, 100, 3))

# input: 100x100 image with 3 channels -> (100, 100, 3) tensor.
# this applies 32 convolution filters of size 3x3 each.
# attribute padding='same' applies zero-padding to the input feature map
# attribute strides=2 applies applies stride of 2
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(100, 100, 3), padding='same', strides=2))

output_feature = model.predict(input_feature)

print('Input size: ({:}, {:}, {:})'.format(input_feature.shape[1], input_feature.shape[2], input_feature.shape[3]))
print('Output size: ({:}, {:}, {:})'.format(output_feature.shape[1], output_feature.shape[2], output_feature.shape[3]))
# Out:
# 1/1 [==============================] - 0s 98ms/step
# Input size: (100, 100, 3)
# Output size: (50, 50, 32)

# %% [markdown]
# ## Activation Functions
#
# As seen in previous tutorials, after a `Dense` layer we usually can find an activation function. We introduce here how to use them after `Conv2D` layers. Those activation functions are a set of operators that maps the feature values to a new set of values, the mapping depends on the function at hand. The main reason for using activation functions is that they add non-linearities to the network, giving more expressive power to the network, which will be able to reproduce more complex functions.
#
#
# The complete list of activation functions that Keras offers can be found [here](https://keras.io/activations/). We introduce here some of them:
#
# *  **Sigmoid Function** sets the output in the range (0, 1). The sigmoid function is widely used in binary classification problems since its output can be taken as a probability value. `keras.activations.sigmoid(x)`:
#
# >![](https://i.ibb.co/Ph8dsTv/sigmoid.png)
#
# *  **Tanh Function** is a logistic function as sigmoid, but the range of the tanh function is (-1, 1). Contrary to sigmoid function, where the values close to 0 are set around 0.5, in the tanh function they will be still mapped around the 0 value. `keras.activations.tanh(x)`:
#
# >![](https://i.ibb.co/68g7LpL/tanh.png)
#
# *  **ReLU Function** is the most common activation function you can find in any current CNN as in general works better than the rest. The range of this function is in \[0, inf). It sets all negative values to 0 and hence is computationally easy to implement. As a drawback, during training some neurons *die*, meaning that the output is 0 for all available data points and no gradient is propagated there. `keras.activations.relu(x, alpha=0.0, max_value=None, threshold=0.0)`:
#
# >![](https://i.ibb.co/Zd9H8Z4/relu.png)
#
# *  **LeakyReLU Function** is a modified version of the ReLU activation above, which attempts to solve the problem of dying neurons that ReLU has. While ReLU does not backpropagate negative values, Leaky ReLU smooths those values without setting them to 0. That allows the gradients to backpropagate through the network even for negative values. `keras.layers.LeakyReLU(alpha=0.3)`:
#
# >![](https://i.ibb.co/dmnJ6h1/leakyrelu.png)
#
# *  **Softmax Function** is another widely activation function for multi-class classification problems and usually is employed as the last activation function in the classification model. This function sets all of the output elements to the range (0, 1). However, the softmax function does not take independently the input values to map it into its probability value. Softmax Function takes an un-normalized vector, $s$, and normalizes it into a probability distribution, $p$, following the softmax expression. As the output is a probability, the output elements add up to 1. `keras.activations.softmax(x, axis=-1)`. Thus, the output value $p_i$ is computed as:
#
# > $p_{i} = \dfrac{e^{s_i}}{\sum_{\substack{j}}^{N} e^{s_j}}$

# %% [markdown]
# The following example shows the feature maps before and after of the ReLU activation function. All values that are negative are set to 0 after the activation function.

# %%
import numpy as np
import keras
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential, Model
from keras.layers import Conv2D, Activation

# Generate dummy data
input_feature = np.random.random((1, 3, 3, 1)) - 0.5

# input: 3x3 image with 1 channel -> (3, 3, 1) tensor.
# This applies a 1 convolution filter of size 3x3 each.
# This applies a ReLU activation function
model = Sequential()
model.add(Conv2D(1, (3, 3), input_shape=(3, 3, 1), padding='same', strides=1, name='conv'))
model.add(Activation('relu'))

model_before_ReLU = Model(inputs=model.input, outputs=model.get_layer('conv').output)

output_feature = model_before_ReLU.predict(input_feature)
output_ReLu_feature = model.predict(input_feature)

print('Output Network without activation function')
print(output_feature)

print('')
print('Output Network after ReLU activation function')
print(output_ReLu_feature)
# Out:
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 33ms/step
# Output Network without activation function
# [[[[ 0.09824473]
#    [ 0.01018265]
#    [-0.01209915]]
#
#   [[ 0.2963006 ]
#    [-0.06293353]
#    [-0.06299474]]
#
#   [[ 0.03987998]
#    [-0.16045052]
#    [ 0.00032717]]]]
#
# Output Network after ReLU activation function
# [[[[0.09824473]
#    [0.01018265]
#    [0.        ]]
#
#   [[0.2963006 ]
#    [0.        ]
#    [0.        ]]
#
#   [[0.03987998]
#    [0.        ]
#    [0.00032717]]]]

# %% [markdown]
# ## Pooling Layer
#
# It is a common practice to insert a pooling layer between convolutional layers in CNNs. In a standard CNN architecture, we set the feature sizes to become smaller progressively to reduce the computation in the networks, and to merge the information from different spatial locations. To reduce the feature map sizes, we can either use bigger stride size in the convolutional layers or we can use pooling layers. Pooling layers perform a spatial sliding window and apply an operation to reduce the spatial size. Those operations vary depending on the architecture, being the max, mean and min pooling the most typical ones. Here, we will explain the max pooling, although all the others work similarly. Max pooling keeps only the max value in a neighbourhood, where the neighbourhood is defined by the size of the kernel. Let's visualise it, the next example shows the result of a Max Pooling layer with a 2x2 kernel and a stride of 2.
#
# ![](https://i.ibb.co/Xp454S4/MaxPool.png)
#
# As in convolutional layers, the final size is conditioned to the stride size of the pooling layer. However, contrary to convolutional layers, pooling layers operate independently on each of the input channels, without modifying the depth of the feature maps. To add max pooling to our model we need to import `MaxPooling2d` from `keras.layers` and define the stride and pooling size.

# %%
import numpy as np
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D, Activation, MaxPooling2D

# Generate dummy data
input_feature = np.random.random((1, 100, 100, 3))

# input: 100x100 image with 3 channels -> (100, 100, 3) tensor.
# this applies 32 convolution filters of size 3x3 each.
# attribute padding='same' applies zero-padding to the input feature map
# attribute strides=1 applies applies stride of 1
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(100, 100, 3), padding='same', strides=1))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='same'))

output_feature = model.predict(input_feature)

print('Input size: ({:}, {:}, {:})'.format(input_feature.shape[1], input_feature.shape[2], input_feature.shape[3]))
print('Output size: ({:}, {:}, {:})'.format(output_feature.shape[1], output_feature.shape[2], output_feature.shape[3]))
# Out:
# 1/1 [==============================] - 0s 64ms/step
# Input size: (100, 100, 3)
# Output size: (50, 50, 32)

# %% [markdown]
# # Example: Classification on MNIST
#
# As opposed to the *Introduction to Keras* tutorial, in this section, we show how to perform image classification when the input data is a 2D image instead of a flat 1D vector.
#
# As discussed above, Convolutional Neural Networks aim to extract and exploit the local relationships on 2D maps, hence, CNNs are much more convenient for images than Multi-layer Perceptron models.
#
# First of all, we load the MNIST dataset from Keras' framework. The definition of the data is almost identical than in the Keras tutorial, although this time we are not reshaping the input images into a 1D vector.

# %%
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, BatchNormalization
from keras.utils import np_utils
from keras.datasets import mnist
from keras.optimizers import RMSprop
from keras.layers import Conv2D, MaxPooling2D, Flatten
import numpy as np

# the data, shuffled and split between train and test sets
# Here we are using the official test set as our validation set, in further
# tutorials, test and validation splits will be explained properly.
# Hence, even though the variables are `x_test` and `y_test`, they represent our validation set
(x_train, y_train), (x_test, y_test) = mnist.load_data()

shape = x_train.shape

# Normalize and reshape the input images
x_train = np.expand_dims(x_train.astype('float32'), -1)
x_test = np.expand_dims(x_test.astype('float32'), -1)

x_train /= 255
x_test /= 255

y_train_class = np_utils.to_categorical(y_train, 10)
y_test_class = np_utils.to_categorical(y_test, 10)

print('Image shape: {0}'.format(x_train.shape[1:]))
print('Total number of training samples: {0}'.format(x_train.shape[0]))
print('Total number of validation samples: {0}'.format(x_test.shape[0]))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step
# Image shape: (28, 28, 1)
# Total number of training samples: 60000
# Total number of validation samples: 10000

# %% [markdown]
# As illustrated in the cell, this time the input image before the model is 28x28x1.
#
# Now we can define a model composed of convolutional layers, activation functions, and maxpool operators:

# %%
model = Sequential()
model.add(Conv2D(16, (3,3), padding='same', input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(16, (3,3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

# %% [markdown]
# As explained in the previous tutorial, in a classification problem, the output of the model is a probability vector. Each dimension of the vector indicates how likely is that the input image belongs to a specific class.
#
# Up to now, the resulting feature map of the model is a map with the shape *Batch x Weight' x Height' x Channel*, and it needs to be mapped into a vector with shape *Batch x Num Classes*. A common technique to process this mapping is to add a Flatten layer that will reshape the feature map to *Batch x (Weight' * Height' * Channel)*. Following the Flatten layer, we add a dense layer which maps this new feature map to the desired output size.

# %%
model.add(Flatten())
model.add(Dense(10))
model.add(Activation('softmax'))

# %% [markdown]
# Let's visualize the output shape in each layer.

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 28, 28, 16)        160
#
#  activation_2 (Activation)   (None, 28, 28, 16)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 16)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 14, 14, 16)        2320
#
#  activation_3 (Activation)   (None, 14, 14, 16)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 7, 7, 16)         0
#  2D)
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 10)                7850
#
#  activation_4 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 10,330
# Trainable params: 10,330
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Finally, we can train our CNN and check its performance on MNIST.

# %%
# initiate RMSprop optimizer
opt = RMSprop(lr=0.0001, decay=1e-6)

model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

model.fit(x_train, y_train_class, batch_size=32, epochs=10,  verbose=0)

score = model.evaluate(x_test, y_test_class, verbose=0)
print('Validation loss:', score[0])
print('Validation accuracy:', score[1])
# Out:
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/rmsprop.py:135: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)
# Validation loss: 0.07754891365766525
# Validation accuracy: 0.9753000140190125

# %% [markdown]
# # Coursework

# %% [markdown]
# ## Task 1: Classification
#
# At this point, we know what is a CNN, how they work, and the components needed to design them. In this first task, we want you to create a CNN that is able to outperform the Multi-layer Perceptron model from Tutorial 1. For the first part of the coursework, we train on CIFAR10, a  classical dataset for image classification. Note that in these tutorials, we mainly use the official test sets of several standard datasets as our validation data. The reason we use the given test sets as validation data for the tutorials is that is an easy way to make sure that we all work with the same split and report results using the same data. However, in a proper machine learning setup, your validation set should be separate from the test set, so you can tune the model/parameters on the validation set and then check the final performance in the test set. Thus, even though the variables are `x_test` and `y_test`, they represent our validation set.
#
# Let's first load the dataset and visualise some examples:

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.utils import np_utils
from keras.datasets import cifar10
from keras.optimizers import RMSprop

# the data, shuffled and split between train and test sets
# Here we are using the official test set as our validation set, in further
# tutorials, test and validation splits will be explained properly.
# Hence, even though the variables are `x_test` and `y_test`, they represent our validation set
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

print('Image shape: {0}'.format(X_train.shape[1:]))
print('Total number of training samples: {0}'.format(X_train.shape[0]))
print('Total number of validation samples: {0}'.format(X_test.shape[0]))

# Let's visualize some examples
N=5
start_val = 0 # pick an element for the code to plot the following N**2 values
fig, axes = plt.subplots(N,N)
items = list(range(0, 10))
for row in range(N):
  for col in range(N):
    idx = start_val+row+N*col
    axes[row,col].imshow(X_train[idx], cmap='gray')
    fig.subplots_adjust(hspace=0.5)
    y_target = int(y_train[idx])
    target = str(items[y_target])
    axes[row,col].set_title(target)
    axes[row,col].set_xticks([])
    axes[row,col].set_yticks([])
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 13s 0us/step
# Image shape: (32, 32, 3)
# Total number of training samples: 50000
# Total number of validation samples: 10000

# %% [markdown]
# CIFAR10 contains 50,000 32x32 color training images, labeled over 10 categories and 10,000 test images. As mentioned, we use those test images as our validation set in this tutorial. We need to preprocess the images for the 1D neural network defined in the previous tutorial:

# %%
# Preprocess dataset for a 1D neural network
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# Normalize the image
X_train /= 255
X_test /= 255

X_train_flatten = X_train.reshape(X_train.shape[0], X_train.shape[1] * X_train.shape[2]*3)
X_test_flatten = X_test.reshape(X_test.shape[0], X_test.shape[1] * X_test.shape[2]*3)

print('New X_train shape: {0}'.format(X_train_flatten.shape))

Y_train_class = np_utils.to_categorical(y_train, 10)
Y_test_class = np_utils.to_categorical(y_test, 10)

print('New Y_train shape: {0}'.format(Y_train_class.shape))
# Out:
# New X_train shape: (50000, 3072)
# New Y_train shape: (50000, 10)

# %% [markdown]
# Now, we are ready to define the Multi-layer Perceptron model and train it.

# %%
model = Sequential()

model.add(Dense(32, activation='relu', input_shape=(X_train_flatten.shape[1:])))
model.add(Dense(64, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))

# initiate RMSprop optimizer
opt = RMSprop(lr=0.0001, decay=1e-6)

# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

model.fit(X_train_flatten, Y_train_class, batch_size=32, epochs=20)

score = model.evaluate(X_test_flatten, Y_test_class, verbose=0)
print('Validation loss:', score[0])
print('Validation accuracy:', score[1])
# Out:
# Epoch 1/20
# 1563/1563 [==============================] - 8s 4ms/step - loss: 1.9423 - accuracy: 0.2847
# Epoch 2/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.7500 - accuracy: 0.3653
# Epoch 3/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.6687 - accuracy: 0.3967
# Epoch 4/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.6163 - accuracy: 0.4217
# Epoch 5/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.5737 - accuracy: 0.4365
# Epoch 6/20
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.5408 - accuracy: 0.4497
# Epoch 7/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.5135 - accuracy: 0.4599
# Epoch 8/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.4873 - accuracy: 0.4695
# Epoch 9/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.4663 - accuracy: 0.4769
# Epoch 10/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.4453 - accuracy: 0.4867
# Epoch 11/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.4290 - accuracy: 0.4912
# Epoch 12/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.4118 - accuracy: 0.4961
# Epoch 13/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.3958 - accuracy: 0.5032
# Epoch 14/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.3800 - accuracy: 0.5090
# Epoch 15/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.3670 - accuracy: 0.5137
# Epoch 16/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.3528 - accuracy: 0.5174
# Epoch 17/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.3383 - accuracy: 0.5238
# Epoch 18/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.3278 - accuracy: 0.5275
# Epoch 19/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.3160 - accuracy: 0.5331
# Epoch 20/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.3038 - accuracy: 0.5364
# Validation loss: 1.395216464996338
# Validation accuracy: 0.5138000249862671

# %% [markdown]
# ### Problem Definition
#
# In this exercise, you are asked to test several CNN architectures in the code provided below. Do not modify the optimizer, loss used or parameters related to the training such as the learning rate, they will be investigated in future tutorials. You must focus on the architecture itself: number of convolutional layers, number of filters in every layer, activation functions, pooling operators, among others. Batch Normalization and Dropout layers, which are quite used in CNN architectures, will be also investigated in a future tutorial so you do not have to discuss them.
#
#
# **Report**:
# *   Present a bar figure with the training and validation accuracies for different design choices. Discuss only the parameters that have a significant influence on the network's performance. Explain any discrepancy between training and validation accuracies.
# *   Present a sketch that introduces your best architecture. See some examples on how to display networks in [cv-tricks' blog](https://cv-tricks.com/cnn/understand-resnet-alexnet-vgg-inception/).

# %%
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.utils import np_utils
from keras.datasets import cifar10
from keras.optimizers import RMSprop
from keras.layers import Conv2D, MaxPooling2D, Flatten, AveragePooling2D
import matplotlib.pyplot as plt
import numpy as np

# the data, shuffled and split between train and val sets
# Here we are using the official test set as our validation set, in further
# tutorials, test and validation splits will be explained properly.
# Hence, even though the variables are `x_test` and `y_test`, they represent our validation set
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

print('Image shape: {0}'.format(x_train.shape[1:]))
print('Total number of training samples: {0}'.format(x_train.shape[0]))
print('Total number of validation samples: {0}'.format(x_test.shape[0]))

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# Normalize the image
x_train /= 255
x_test /= 255

y_train_class = np_utils.to_categorical(y_train, 10)
y_test_class = np_utils.to_categorical(y_test, 10)


# . . . 


# Define here your architecture

# . . . 

def evaluate_model_classification(model, acc_dict, comment=""):
    # initiate RMSprop optimizer
    opt = RMSprop(learning_rate=0.0001, decay=1e-6)

    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

    model.fit(x_train, y_train_class, batch_size=32, epochs=20, verbose=False)

    print('Model', comment)
    train_score = model.evaluate(x_train, y_train_class, verbose=0)
    print('Training loss:\t\t', train_score[0])
    print('Training accuracy:\t', train_score[1])

    val_score = model.evaluate(x_test, y_test_class, verbose=0)
    print('Validation loss:\t', val_score[0])
    print('Validation accuracy:\t', val_score[1])
    print()

    acc_dict['train'].append(train_score[1])
    acc_dict['val'].append(val_score[1])
    return acc_dict

def bar_plot(train_accs, val_accs, xlabel="", xticks=[]):

    bar_width = 0.25

    X = np.arange(len(train_accs))
    plt.bar(X, train_accs, color='C0', width=bar_width, label="train")
    plt.bar(X + bar_width, val_accs, color='C1', width=bar_width, label="val")

    plt.xlabel(xlabel)
    plt.ylabel('Accuracy')
    plt.xticks(X + bar_width/2, xticks)

    plt.legend(loc="lower right")
    plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step
# Image shape: (32, 32, 3)
# Total number of training samples: 50000
# Total number of validation samples: 10000

# %% [markdown]
# #### Designs
# 1. 2 conv layers, kernel size 3
# 2. 3 conv layers, increasing kernel size
# 3. 4 conv layers, increasing no. of filters
# 4. 2 conv layers, activation functions
# 5. 2 conv layers, average pooling

# %%
accuracies = {
    'train': [], 
    'val': []
}

# Model 1: simple
m1 = Sequential()
m1.add(Conv2D(32, (3,3), padding='same', input_shape=x_train.shape[1:]))
m1.add(Activation('relu'))
m1.add(MaxPooling2D(pool_size=(2,2)))
m1.add(Conv2D(32, (3,3), padding='same'))
m1.add(Activation('relu'))
m1.add(MaxPooling2D(pool_size=(2,2)))
m1.add(Flatten())
m1.add(Dense(128, activation ='relu'))
m1.add(Dense(10, activation = 'softmax'))

# Model 2: more conv layers
m2 = Sequential()
m2.add(Conv2D(16, (7,7), padding='same', input_shape=x_train.shape[1:]))
m2.add(Activation('relu'))
m2.add(MaxPooling2D(pool_size=(2,2)))
m2.add(Conv2D(32, (5,5), padding='same'))
m2.add(Activation('relu'))
m2.add(Conv2D(128, (3,3), padding='same'))
m2.add(Activation('relu'))
m2.add(MaxPooling2D(pool_size=(2,2)))
m2.add(Conv2D(256, (3,3), padding='same'))
m2.add(Activation('relu'))
m2.add(Flatten())
m2.add(Dense(128, activation ='relu'))
m2.add(Dense(10, activation = 'softmax'))

# Model 3: varying strides
m3 = Sequential()
m3.add(Conv2D(16, (7,7), strides=(2,2), padding='same', input_shape=x_train.shape[1:]))
m3.add(Activation('relu'))
m3.add(MaxPooling2D(pool_size=(2,2)))
m3.add(Conv2D(32, (5,5), strides=(2,2), padding='same'))
m3.add(Activation('relu'))
m3.add(Conv2D(128, (3,3), strides=(1,1), padding='same'))
m3.add(Activation('relu'))
m3.add(MaxPooling2D(pool_size=(2,2)))
m3.add(Conv2D(256, (3,3), strides=(1,1), padding='same'))
m3.add(Activation('relu'))
m3.add(Flatten())
m3.add(Dense(128, activation ='relu'))
m3.add(Dense(10, activation = 'softmax'))

# Model 4: sigmoid activation
m4 = Sequential()
m4.add(Conv2D(32, (3,3), padding='same', input_shape=x_train.shape[1:]))
m4.add(Activation('sigmoid'))
m4.add(MaxPooling2D(pool_size=(2,2)))
m4.add(Conv2D(32, (3,3), padding='same'))
m4.add(Activation('sigmoid'))
m4.add(MaxPooling2D(pool_size=(2,2)))
m4.add(Flatten())
m4.add(Dense(128, activation ='sigmoid'))
m4.add(Dense(10, activation = 'softmax'))

# Model 5: average pooling
m5 = Sequential()
m5.add(Conv2D(32, (3,3), padding='same', input_shape=x_train.shape[1:]))
m5.add(Activation('relu'))
m5.add(AveragePooling2D(pool_size=(2,2)))
m5.add(Conv2D(32, (3,3), padding='same'))
m5.add(Activation('relu'))
m5.add(AveragePooling2D(pool_size=(2,2)))
m5.add(Flatten())
m5.add(Dense(128, activation ='relu'))
m5.add(Dense(10, activation = 'softmax'))

evaluate_model_classification(m1, accuracies, "1: default")
evaluate_model_classification(m2, accuracies, "2: more conv layers")
evaluate_model_classification(m3, accuracies, "3: varying strides")
evaluate_model_classification(m4, accuracies, "4: sigmoid activation")
evaluate_model_classification(m5, accuracies, "5: average pooling")

bar_plot(accuracies['train'], accuracies ['val'],
         xlabel = "Model",
         xticks = ['1','2','3','4','5'])
# Out:
# Model 1: default
# Training loss:		 0.7967183589935303
# Training accuracy:	 0.7252200245857239
# Validation loss:	 0.9380373954772949
# Validation accuracy:	 0.6809999942779541
#
# Model 2: more conv layers
# Training loss:		 0.09107325971126556
# Training accuracy:	 0.9743000268936157
# Validation loss:	 1.3421213626861572
# Validation accuracy:	 0.7060999870300293
#
# Model 3: varying strides
# Training loss:		 0.7190037369728088
# Training accuracy:	 0.7494999766349792
# Validation loss:	 1.0410990715026855
# Validation accuracy:	 0.6450999975204468
#
# Model 4: sigmoid activation
# Training loss:		 1.480629324913025
# Training accuracy:	 0.47694000601768494
# Validation loss:	 1.488786220550537
# Validation accuracy:	 0.4722000062465668
#
# Model 5: average pooling
# Training loss:		 0.917830228805542
# Training accuracy:	 0.6822400093078613
# Validation loss:	 1.0200730562210083
# Validation accuracy:	 0.6376000046730042

# %%
m1.summary()
m2.summary()
m3.summary()
m4.summary()
m5.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_37 (Conv2D)          (None, 32, 32, 32)        896
#
#  activation_42 (Activation)  (None, 32, 32, 32)        0
#
#  max_pooling2d_31 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  conv2d_38 (Conv2D)          (None, 16, 16, 32)        9248
#
#  activation_43 (Activation)  (None, 16, 16, 32)        0
#
#  max_pooling2d_32 (MaxPoolin  (None, 8, 8, 32)         0
#  g2D)
#
#  flatten_12 (Flatten)        (None, 2048)              0
#
#  dense_24 (Dense)            (None, 128)               262272
#
#  dense_25 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 273,706
# Trainable params: 273,706
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_39 (Conv2D)          (None, 32, 32, 16)        2368
#
#  activation_44 (Activation)  (None, 32, 32, 16)        0
#
#  max_pooling2d_33 (MaxPoolin  (None, 16, 16, 16)       0
#  g2D)
#
#  conv2d_40 (Conv2D)          (None, 16, 16, 32)        12832
#
#  activation_45 (Activation)  (None, 16, 16, 32)        0
#
#  conv2d_41 (Conv2D)          (None, 16, 16, 128)       36992
#
#  activation_46 (Activation)  (None, 16, 16, 128)       0
#
#  max_pooling2d_34 (MaxPoolin  (None, 8, 8, 128)        0
#  g2D)
#
#  conv2d_42 (Conv2D)          (None, 8, 8, 256)         295168
#
#  activation_47 (Activation)  (None, 8, 8, 256)         0
#
#  flatten_13 (Flatten)        (None, 16384)             0
#
#  dense_26 (Dense)            (None, 128)               2097280
#
#  dense_27 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 2,445,930
# Trainable params: 2,445,930
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_43 (Conv2D)          (None, 16, 16, 16)        2368
#
#  activation_48 (Activation)  (None, 16, 16, 16)        0
#
#  max_pooling2d_35 (MaxPoolin  (None, 8, 8, 16)         0
#  g2D)
#
#  conv2d_44 (Conv2D)          (None, 4, 4, 32)          12832
#
#  activation_49 (Activation)  (None, 4, 4, 32)          0
#
#  conv2d_45 (Conv2D)          (None, 4, 4, 128)         36992
#
#  activation_50 (Activation)  (None, 4, 4, 128)         0
#
#  max_pooling2d_36 (MaxPoolin  (None, 2, 2, 128)        0
#  g2D)
#
#  conv2d_46 (Conv2D)          (None, 2, 2, 256)         295168
#
#  activation_51 (Activation)  (None, 2, 2, 256)         0
#
#  flatten_14 (Flatten)        (None, 1024)              0
#
#  dense_28 (Dense)            (None, 128)               131200
#
#  dense_29 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 479,850
# Trainable params: 479,850
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_47 (Conv2D)          (None, 32, 32, 32)        896
#
#  activation_52 (Activation)  (None, 32, 32, 32)        0
#
#  max_pooling2d_37 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  conv2d_48 (Conv2D)          (None, 16, 16, 32)        9248
#
#  activation_53 (Activation)  (None, 16, 16, 32)        0
#
#  max_pooling2d_38 (MaxPoolin  (None, 8, 8, 32)         0
#  g2D)
#
#  flatten_15 (Flatten)        (None, 2048)              0
#
#  dense_30 (Dense)            (None, 128)               262272
#
#  dense_31 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 273,706
# Trainable params: 273,706
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_49 (Conv2D)          (None, 32, 32, 32)        896
#
#  activation_54 (Activation)  (None, 32, 32, 32)        0
#
#  average_pooling2d_4 (Averag  (None, 16, 16, 32)       0
#  ePooling2D)
#
#  conv2d_50 (Conv2D)          (None, 16, 16, 32)        9248
#
#  activation_55 (Activation)  (None, 16, 16, 32)        0
#
#  average_pooling2d_5 (Averag  (None, 8, 8, 32)         0
#  ePooling2D)
#
#  flatten_16 (Flatten)        (None, 2048)              0
#
#  dense_32 (Dense)            (None, 128)               262272
#
#  dense_33 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 273,706
# Trainable params: 273,706
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Number of filters
# 2 convolutional layers, kernel size of 3

# %%
print("Number of Filters")

accs_filter = {
    'train': [], 
    'val': []
}

# Model 1: 4 filters
m1 = Sequential()
m1.add(Conv2D(4, (3,3), padding='same', input_shape=x_train.shape[1:]))
m1.add(Activation('relu'))
m1.add(MaxPooling2D(pool_size=(2,2)))
m1.add(Conv2D(4, (3,3), padding='same'))
m1.add(Activation('relu'))
m1.add(MaxPooling2D(pool_size=(2,2)))
m1.add(Flatten())
m1.add(Dense(128, activation ='relu'))
m1.add(Dense(10))
m1.add(Activation('softmax'))

# Model 2: 16 filters
m2 = Sequential()
m2.add(Conv2D(16, (3,3), padding='same', input_shape=x_train.shape[1:]))
m2.add(Activation('relu'))
m2.add(MaxPooling2D(pool_size=(2,2)))
m2.add(Conv2D(16, (3,3), padding='same'))
m2.add(Activation('relu'))
m2.add(MaxPooling2D(pool_size=(2,2)))
m2.add(Flatten())
m2.add(Dense(128, activation ='relu'))
m2.add(Dense(10))
m2.add(Activation('softmax'))

# Model 3: 32 filters
m3 = Sequential()
m3.add(Conv2D(32, (3,3), padding='same', input_shape=x_train.shape[1:]))
m3.add(Activation('relu'))
m3.add(MaxPooling2D(pool_size=(2,2)))
m3.add(Conv2D(32, (3,3), padding='same'))
m3.add(Activation('relu'))
m3.add(MaxPooling2D(pool_size=(2,2)))
m3.add(Flatten())
m3.add(Dense(128, activation ='relu'))
m3.add(Dense(10))
m3.add(Activation('softmax'))

# Model 4: 100 filters
m4 = Sequential()
m4.add(Conv2D(100, (3,3), padding='same', input_shape=x_train.shape[1:]))
m4.add(Activation('relu'))
m4.add(MaxPooling2D(pool_size=(2,2)))
m4.add(Conv2D(100, (3,3), padding='same'))
m4.add(Activation('relu'))
m4.add(MaxPooling2D(pool_size=(2,2)))
m4.add(Flatten())
m4.add(Dense(128, activation ='relu'))
m4.add(Dense(10))
m4.add(Activation('softmax'))

# Model 5: 200 filters
m5 = Sequential()
m5.add(Conv2D(200, (3,3), padding='same', input_shape=x_train.shape[1:]))
m5.add(Activation('relu'))
m5.add(MaxPooling2D(pool_size=(2,2)))
m5.add(Conv2D(200, (3,3), padding='same'))
m5.add(Activation('relu'))
m5.add(MaxPooling2D(pool_size=(2,2)))
m5.add(Flatten())
m5.add(Dense(128, activation ='relu'))
m5.add(Dense(10))
m5.add(Activation('softmax'))

evaluate_model_classification(m1, accs_filter, "1: 4 filters")
evaluate_model_classification(m2, accs_filter, "2: 16 filters")
evaluate_model_classification(m3, accs_filter, "3: 32 filters")
evaluate_model_classification(m4, accs_filter, "4: 100 filters")
evaluate_model_classification(m5, accs_filter, "5: 200 filters")

bar_plot(accs_filter['train'], accs_filter['val'],
         xlabel = "Number of filters in each layer",
         xticks = ['4','16','32','100','200'])
# Out:
# Number of Filters
# Model 1: 4 filters
# Training loss:		 1.3703559637069702
# Training accuracy:	 0.515779972076416
# Validation loss:	 1.3963929414749146
# Validation accuracy:	 0.5060999989509583
#
# Model 2: 16 filters
# Training loss:		 0.9806406497955322
# Training accuracy:	 0.6560999751091003
# Validation loss:	 1.0726525783538818
# Validation accuracy:	 0.6255000233650208
#
# Model 3: 32 filters
# Training loss:		 0.8155561089515686
# Training accuracy:	 0.71697998046875
# Validation loss:	 0.9665306806564331
# Validation accuracy:	 0.6646999716758728
#
# Model 4: 100 filters
# Training loss:		 0.5131577849388123
# Training accuracy:	 0.8252999782562256
# Validation loss:	 0.870290219783783
# Validation accuracy:	 0.7145000100135803
#
# Model 5: 200 filters
# Training loss:		 0.3286277651786804
# Training accuracy:	 0.8889999985694885
# Validation loss:	 0.9127368927001953
# Validation accuracy:	 0.7279000282287598

# %% [markdown]
# #### Kernel size
# 2 convolutional layers, 32 filters per layer

# %%
print("Kernel size")

accs_kernel = {
    'train': [], 
    'val': []
}

# Model 1: kernel=3
m1 = Sequential()
m1.add(Conv2D(100, (3,3), padding='same', input_shape=x_train.shape[1:]))
m1.add(Activation('relu'))
m1.add(MaxPooling2D(pool_size=(2,2)))
m1.add(Conv2D(100, (3,3), padding='same'))
m1.add(Activation('relu'))
m1.add(MaxPooling2D(pool_size=(2,2)))
m1.add(Flatten())
m1.add(Dense(128, activation ='relu'))
m1.add(Dense(10))
m1.add(Activation('softmax'))

# Model 2: kernel=5
m2 = Sequential()
m2.add(Conv2D(100, (5,5), padding='same', input_shape=x_train.shape[1:]))
m2.add(Activation('relu'))
m2.add(MaxPooling2D(pool_size=(2,2)))
m2.add(Conv2D(100, (5,5), padding='same'))
m2.add(Activation('relu'))
m2.add(MaxPooling2D(pool_size=(2,2)))
m2.add(Flatten())
m2.add(Dense(128, activation ='relu'))
m2.add(Dense(10))
m2.add(Activation('softmax'))

# Model 3: kernel=7
m3 = Sequential()
m3.add(Conv2D(100, (7,7), padding='same', input_shape=x_train.shape[1:]))
m3.add(Activation('relu'))
m3.add(MaxPooling2D(pool_size=(2,2)))
m3.add(Conv2D(100, (7,7), padding='same'))
m3.add(Activation('relu'))
m3.add(MaxPooling2D(pool_size=(2,2)))
m3.add(Flatten())
m3.add(Dense(128, activation ='relu'))
m3.add(Dense(10))
m3.add(Activation('softmax'))

# Model 4: kernel=3,5
m4 = Sequential()
m4.add(Conv2D(100, (3,3), padding='same', input_shape=x_train.shape[1:]))
m4.add(Activation('relu'))
m4.add(MaxPooling2D(pool_size=(2,2)))
m4.add(Conv2D(100, (5,5), padding='same'))
m4.add(Activation('relu'))
m4.add(MaxPooling2D(pool_size=(2,2)))
m4.add(Flatten())
m4.add(Dense(128, activation ='relu'))
m4.add(Dense(10))
m4.add(Activation('softmax'))

# Model 5: kernel=5,3
m5 = Sequential()
m5.add(Conv2D(100, (5,5), padding='same', input_shape=x_train.shape[1:]))
m5.add(Activation('relu'))
m5.add(MaxPooling2D(pool_size=(2,2)))
m5.add(Conv2D(100, (3,3), padding='same'))
m5.add(Activation('relu'))
m5.add(MaxPooling2D(pool_size=(2,2)))
m5.add(Flatten())
m5.add(Dense(128, activation ='relu'))
m5.add(Dense(10))
m5.add(Activation('softmax'))

evaluate_model_classification(m1, accs_kernel, "1: kernel=3")
evaluate_model_classification(m2, accs_kernel, "2: kernel=5")
evaluate_model_classification(m3, accs_kernel, "3: kernel=7")
evaluate_model_classification(m4, accs_kernel, "4: kernel=3,5 (increasing)")
evaluate_model_classification(m5, accs_kernel, "5: kernel=5,3 (decreasing)")

bar_plot(accs_kernel['train'], accs_kernel['val'],
         xlabel = "Kernel size",
         xticks = ['3', '5', '7', '3,5 (↑)', '5,3 (↓)'])
# Out:
# Kernel size
# Model 1: kernel=3
# Training loss:		 0.502641499042511
# Training accuracy:	 0.8314999938011169
# Validation loss:	 0.850211501121521
# Validation accuracy:	 0.7182000279426575
#
# Model 2: kernel=5
# Training loss:		 0.2836717367172241
# Training accuracy:	 0.906000018119812
# Validation loss:	 0.8936601281166077
# Validation accuracy:	 0.7376000285148621
#
# Model 3: kernel=7
# Training loss:		 0.1590757817029953
# Training accuracy:	 0.9556599855422974
# Validation loss:	 1.0434367656707764
# Validation accuracy:	 0.7275999784469604
#
# Model 4: kernel=3,5 (increasing)
# Training loss:		 0.3419937193393707
# Training accuracy:	 0.8899199962615967
# Validation loss:	 0.8416339159011841
# Validation accuracy:	 0.732200026512146
#
# Model 5: kernel=5,3 (decreasing)
# Training loss:		 0.41774898767471313
# Training accuracy:	 0.8610000014305115
# Validation loss:	 0.8743712902069092
# Validation accuracy:	 0.7182999849319458

# %% [markdown]
# #### Stride length
# 2 convolutional layers, 100 filters per layer, kernel=3,5

# %%
print("Stride size")

accs_stride = {
    'train': [], 
    'val': []
}

# Model 1: stride=1
m1 = Sequential()
m1.add(Conv2D(100, (3,5), strides=(1,1), padding='same', input_shape=x_train.shape[1:]))
m1.add(Activation('relu'))
m1.add(MaxPooling2D(pool_size=(2,2)))
m1.add(Conv2D(100, (3,5), strides=(1,1), padding='same'))
m1.add(Activation('relu'))
m1.add(MaxPooling2D(pool_size=(2,2)))
m1.add(Flatten())
m1.add(Dense(128, activation ='relu'))
m1.add(Dense(10))
m1.add(Activation('softmax'))

# Model 2: stride=2
m2 = Sequential()
m2.add(Conv2D(100, (3,5), strides=(2,2), padding='same', input_shape=x_train.shape[1:]))
m2.add(Activation('relu'))
m2.add(MaxPooling2D(pool_size=(2,2)))
m2.add(Conv2D(100, (3,5), strides=(2,2), padding='same'))
m2.add(Activation('relu'))
m2.add(MaxPooling2D(pool_size=(2,2)))
m2.add(Flatten())
m2.add(Dense(128, activation ='relu'))
m2.add(Dense(10))
m2.add(Activation('softmax'))

# Model 3: stride=3
m3 = Sequential()
m3.add(Conv2D(100, (3,5), strides=(3,3), padding='same', input_shape=x_train.shape[1:]))
m3.add(Activation('relu'))
m3.add(MaxPooling2D(pool_size=(2,2)))
m3.add(Conv2D(100, (3,5), strides=(3,3), padding='same'))
m3.add(Activation('relu'))
m3.add(MaxPooling2D(pool_size=(2,2)))
m3.add(Flatten())
m3.add(Dense(128, activation ='relu'))
m3.add(Dense(10))
m3.add(Activation('softmax'))

# Model 4: stride=1,2
m4 = Sequential()
m4.add(Conv2D(100, (3,5), strides=(1,2), padding='same', input_shape=x_train.shape[1:]))
m4.add(Activation('relu'))
m4.add(MaxPooling2D(pool_size=(2,2)))
m4.add(Conv2D(100, (3,5), strides=(1,2), padding='same'))
m4.add(Activation('relu'))
m4.add(MaxPooling2D(pool_size=(2,2)))
m4.add(Flatten())
m4.add(Dense(128, activation ='relu'))
m4.add(Dense(10))
m4.add(Activation('softmax'))

evaluate_model_classification(m1, accs_stride, "1: stride=1")
evaluate_model_classification(m2, accs_stride, "2: stride=2")
evaluate_model_classification(m3, accs_stride, "3: stride=3")
evaluate_model_classification(m4, accs_stride, "4: stride=(1,2) (non-square)")

bar_plot(accs_stride['train'], accs_stride['val'],
         xlabel = 'Stride length',
         xticks = ['(1,1)', '(2,2)', '(3,3)', '(1,2)'])
# Out:
# Stride size
# Model 1: stride=1
# Training loss:		 0.4118838608264923
# Training accuracy:	 0.8593599796295166
# Validation loss:	 0.8776999115943909
# Validation accuracy:	 0.7197999954223633
#
# Model 2: stride=2
# Training loss:		 0.852428138256073
# Training accuracy:	 0.7089599967002869
# Validation loss:	 1.0125389099121094
# Validation accuracy:	 0.6535999774932861
#
# Model 3: stride=3
# Training loss:		 1.0113948583602905
# Training accuracy:	 0.6467199921607971
# Validation loss:	 1.1030360460281372
# Validation accuracy:	 0.6093000173568726
#
# Model 4: stride=(1,2) (non-square)
# Training loss:		 0.6485767364501953
# Training accuracy:	 0.7796199917793274
# Validation loss:	 0.8569427728652954
# Validation accuracy:	 0.7055000066757202

# %% [markdown]
# #### Activation functions
# 2 convolutional layers, 100 filters per layer, kernel=3,5

# %%
print("Activation functions")

accs_act = {
    'train': [], 
    'val': []
}

def make_model(func):
    model = Sequential()
    model.add(Conv2D(100, (3,5), strides=(1,1), padding='same', input_shape=x_train.shape[1:]))
    model.add(Activation(func))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Conv2D(100, (3,5), strides=(1,1), padding='same'))
    model.add(Activation(func))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Flatten())
    model.add(Dense(128, activation=func))
    model.add(Dense(10))
    model.add(Activation('softmax'))
    return model

m1 = make_model('relu')
m2 = make_model('sigmoid')
m3 = make_model('tanh')

evaluate_model_classification(m1, accs_act, "1: relu")
evaluate_model_classification(m2, accs_act, "2: sigmoid")
evaluate_model_classification(m3, accs_act, "3: tanh")

bar_plot(accs_act['train'], accs_act['val'],
         xlabel = "Activation function",
         xticks = ['reLU', 'sigmoid', 'tanh'])
# Out:
# Activation functions
# Model 1: relu
# Training loss:		 0.4167291820049286
# Training accuracy:	 0.8614599704742432
# Validation loss:	 0.879324197769165
# Validation accuracy:	 0.7170000076293945
#
# Model 2: sigmoid
# Training loss:		 1.3454668521881104
# Training accuracy:	 0.5227000117301941
# Validation loss:	 1.3816567659378052
# Validation accuracy:	 0.5131000280380249
#
# Model 3: tanh
# Training loss:		 0.3200979232788086
# Training accuracy:	 0.9063400030136108
# Validation loss:	 0.9728359580039978
# Validation accuracy:	 0.6854000091552734

# %% [markdown]
# #### Pooling operators
# 2 convolutional layers, 100 filters per layer, kernel=3,5

# %%
print("Pooling operators")

accs_pool = {
    'train': [],
    'val': []
}

def make_model(num):
    def add_pooling(model, num):
        if num == 1:
            model.add(MaxPooling2D(pool_size=(2,2)))
        elif num == 2:
            model.add(AveragePooling2D(pool_size=(2,2)))
        elif num == 3:
            model.add(MaxPooling2D(pool_size=(4,4)))
        elif num == 4:
            model.add(AveragePooling2D(pool_size=(4,4)))
        return model

    model = Sequential()
    model.add(Conv2D(100, (3,5), strides=(1,1), padding='same', input_shape=x_train.shape[1:]))
    model.add(Activation('relu'))
    model = add_pooling(model, num)
    model.add(Conv2D(100, (3,5), strides=(1,1), padding='same'))
    model.add(Activation('relu'))
    model = add_pooling(model, num)
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dense(10))
    model.add(Activation('softmax'))
    return model

m1 = make_model(1)
m2 = make_model(2)
m3 = make_model(3)
m4 = make_model(4)

evaluate_model_classification(m1, accs_pool, "1: max pooling (size=2)")
evaluate_model_classification(m2, accs_pool, "2: average pooling (size=2)")
evaluate_model_classification(m3, accs_pool, "3: max pooling (size=4)")
evaluate_model_classification(m4, accs_pool, "4: average pooling (size=4)")

bar_plot(accs_pool['train'], accs_pool['val'],
         xlabel = "Pooling operator",
         xticks = ['Max (size=2)', 'Avg (size=2)', 'Max (size=4)', 'Avg (size=4)'])
# Out:
# Pooling operators
# Model 1: max pooling (size=2)
# Training loss:		 0.42566975951194763
# Training accuracy:	 0.8586000204086304
# Validation loss:	 0.8799020648002625
# Validation accuracy:	 0.7181000113487244
#
# Model 2: average pooling (size=2)
# Training loss:		 0.6492933630943298
# Training accuracy:	 0.7739400267601013
# Validation loss:	 0.9042150378227234
# Validation accuracy:	 0.6879000067710876
#
# Model 3: max pooling (size=4)
# Training loss:		 0.7796363830566406
# Training accuracy:	 0.73225998878479
# Validation loss:	 0.9127504825592041
# Validation accuracy:	 0.6832000017166138
#
# Model 4: average pooling (size=4)
# Training loss:		 1.2179046869277954
# Training accuracy:	 0.5710800290107727
# Validation loss:	 1.2278506755828857
# Validation accuracy:	 0.5659999847412109

# %% [markdown]
# ---
# ---
#
# ## Task 2: Regression
#
# Now we face a regression task instead of a classification problem. Loss function, activations, and dataset will change in the following task. Thus, instead of having one vector with the probabilities of each class, in this regression problem, the output is a single scalar.
#
# For this second task, we chose the task of estimating house prices based on input images. To get the data run the following script, which clones Ahmed and Moustafa’s [repository](https://github.com/emanhamed/Houses-dataset) into colmap.

# %%
# !git clone https://github.com/emanhamed/Houses-dataset
# %cd /content/Houses-dataset/Houses\ Dataset
# Out:
# Cloning into 'Houses-dataset'...
# remote: Enumerating objects: 2166, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 2166 (delta 0), reused 0 (delta 0), pack-reused 2165
# Receiving objects: 100% (2166/2166), 176.26 MiB | 49.92 MiB/s, done.
# Resolving deltas: 100% (20/20), done.
# /content/Houses-dataset/Houses Dataset

# %% [markdown]
# This dataset contains four images of the house (kitchen, frontal, bedroom and bathroom), and attributes (number of bedrooms, number of bathrooms, zip code...). For our exercise, we only use the images of the house. We start with front door images.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from numpy.random import seed

def import_images(house_section='frontal'):

    # house_section = 'frontal' # select between: kitchen, frontal, bedroom or bathroom
    print('We have selected {} images. You can switch to the kitchen, frontal, bedroom or bathroom images by changing house_section variable.'.format(house_section))
    images = []
    for i_im in range(1, 536):
        image = cv2.imread(str(i_im)+'_'+house_section+'.jpg')
        image = cv2.resize(image, (64, 64))
        images.append(image)

    labels = []
    f = open('HousesInfo.txt', "r")
    for x in f:
        label = (x).split(' ')[-1].split('\n')[0]
        labels.append(label)

    # Let's visualize some examples
    N=3
    start_val = 0 # pick an element for the code to plot the following N**2 values
    fig, axes = plt.subplots(N,N)
    for row in range(N):
        for col in range(N):
            idx = start_val+row+N*col    
            tmp = cv2.cvtColor(images[idx],cv2.COLOR_BGR2RGB)
            axes[row,col].imshow(tmp, cmap='gray')
            fig.subplots_adjust(hspace=0.5)
            target = int(labels[idx])
            axes[row,col].set_title(str(target) + '$')
            axes[row,col].set_xticks([])
            axes[row,col].set_yticks([])
    
    plt.show()

    return images, labels

# %% [markdown]
# Prepare the dataset for training the model:

# %%
def prepare_dataset(images, labels):
    seed(1234)

    images = np.asarray(images).astype('float32')
    labels = np.asarray(labels).astype('float32')

    # Normalize the image
    max_price = labels.max()
    images /= 255.
    labels /= max_price

    random_idx = np.random.permutation(len(images))
    images = images[random_idx]
    labels = labels[random_idx]

    split_size_val = int(0.8*len(images))
    X_train, X_val = images[:split_size_val], images[split_size_val+1:]
    Y_train, Y_val = labels[:split_size_val], labels[split_size_val+1:]

    # Print shape of training and val images 
    print('X_train image shape: {0}'.format(X_train.shape))
    print('X_val image shape: {0}'.format(X_val.shape))

    # Print shape of training and val labels 
    print('Y_train labels shape: {0}'.format(Y_train.shape))
    print('Y_val labels shape: {0}'.format(Y_val.shape))

    return X_train, X_val, Y_train, Y_val

images, labels = import_images('frontal')
X_train, X_val, Y_train, Y_val = prepare_dataset(images, labels)
# Out:
# We have selected frontal images. You can switch to the kitchen, frontal, bedroom or bathroom images by changing house_section variable.
# X_train image shape: (428, 64, 64, 3)
# X_val image shape: (106, 64, 64, 3)
# Y_train labels shape: (428,)
# Y_val labels shape: (106,)

# %% [markdown]
# ### Problem Definition
#
# Similar to the previous task, you are asked to design a CNN architecture able to perform the estimation of house prices based on the `frontal` house image. Design a new model by changing parameters such as the number of convolutional layers, activation functions, strides, or pooling operators, among others.

# %%
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.utils import np_utils
from keras.optimizers import Adam
from keras.layers import Conv2D, MaxPooling2D, Flatten
tf.random.set_seed(1234)

chanDim = -1
model = Sequential()

# . . . 

# Define here your architecture

# . . . 

model.summary()
opt = Adam(lr=1e-3, decay=1e-3 / 200)
model.compile(loss="mean_absolute_percentage_error", optimizer=opt, metrics=['mean_absolute_percentage_error'])

# train the model
print("[INFO] training model...")
history = model.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=100, batch_size=32)
# Out:
# Model: "sequential_49"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_98 (Conv2D)          (None, 64, 64, 16)        448
#
#  activation_115 (Activation)  (None, 64, 64, 16)       0
#
#  max_pooling2d_80 (MaxPoolin  (None, 32, 32, 16)       0
#  g2D)
#
#  flatten_46 (Flatten)        (None, 16384)             0
#
#  dense_122 (Dense)           (None, 64)                1048640
#
#  dense_123 (Dense)           (None, 1)                 65
#
# =================================================================
# Total params: 1,049,153
# Trainable params: 1,049,153
# Non-trainable params: 0
# _________________________________________________________________
# [INFO] training model...
# Epoch 1/100
# 14/14 [==============================] - 1s 16ms/step - loss: 2318.4753 - mean_absolute_percentage_error: 2318.4753 - val_loss: 95.4896 - val_mean_absolute_percentage_error: 95.4896
# Epoch 2/100
# 14/14 [==============================] - 0s 7ms/step - loss: 86.4542 - mean_absolute_percentage_error: 86.4542 - val_loss: 77.4016 - val_mean_absolute_percentage_error: 77.4016
# Epoch 3/100
# 14/14 [==============================] - 0s 7ms/step - loss: 71.9064 - mean_absolute_percentage_error: 71.9064 - val_loss: 69.5953 - val_mean_absolute_percentage_error: 69.5953
# Epoch 4/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2654 - mean_absolute_percentage_error: 70.2654 - val_loss: 67.6768 - val_mean_absolute_percentage_error: 67.6768
# Epoch 5/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.4224 - mean_absolute_percentage_error: 70.4224 - val_loss: 67.8136 - val_mean_absolute_percentage_error: 67.8136
# Epoch 6/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.3407 - mean_absolute_percentage_error: 70.3407 - val_loss: 68.6686 - val_mean_absolute_percentage_error: 68.6686
# Epoch 7/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.3533 - mean_absolute_percentage_error: 70.3533 - val_loss: 69.5296 - val_mean_absolute_percentage_error: 69.5296
# Epoch 8/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2268 - mean_absolute_percentage_error: 70.2268 - val_loss: 69.0811 - val_mean_absolute_percentage_error: 69.0811
# Epoch 9/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2230 - mean_absolute_percentage_error: 70.2230 - val_loss: 69.6013 - val_mean_absolute_percentage_error: 69.6013
# Epoch 10/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2533 - mean_absolute_percentage_error: 70.2533 - val_loss: 69.4026 - val_mean_absolute_percentage_error: 69.4026
# Epoch 11/100
# 14/14 [==============================] - 0s 6ms/step - loss: 70.2337 - mean_absolute_percentage_error: 70.2337 - val_loss: 69.3784 - val_mean_absolute_percentage_error: 69.3784
# Epoch 12/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2329 - mean_absolute_percentage_error: 70.2329 - val_loss: 68.7448 - val_mean_absolute_percentage_error: 68.7448
# Epoch 13/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2186 - mean_absolute_percentage_error: 70.2186 - val_loss: 69.2874 - val_mean_absolute_percentage_error: 69.2874
# Epoch 14/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2644 - mean_absolute_percentage_error: 70.2644 - val_loss: 69.6661 - val_mean_absolute_percentage_error: 69.6661
# Epoch 15/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2283 - mean_absolute_percentage_error: 70.2283 - val_loss: 69.0515 - val_mean_absolute_percentage_error: 69.0515
# Epoch 16/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2401 - mean_absolute_percentage_error: 70.2401 - val_loss: 68.7959 - val_mean_absolute_percentage_error: 68.7959
# Epoch 17/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2502 - mean_absolute_percentage_error: 70.2502 - val_loss: 69.1585 - val_mean_absolute_percentage_error: 69.1585
# Epoch 18/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2478 - mean_absolute_percentage_error: 70.2478 - val_loss: 68.9479 - val_mean_absolute_percentage_error: 68.9479
# Epoch 19/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.3852 - mean_absolute_percentage_error: 70.3852 - val_loss: 69.4668 - val_mean_absolute_percentage_error: 69.4668
# Epoch 20/100
# 14/14 [==============================] - 0s 6ms/step - loss: 70.1864 - mean_absolute_percentage_error: 70.1864 - val_loss: 68.8904 - val_mean_absolute_percentage_error: 68.8904
# Epoch 21/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.3575 - mean_absolute_percentage_error: 70.3575 - val_loss: 68.2003 - val_mean_absolute_percentage_error: 68.2003
# Epoch 22/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3409 - mean_absolute_percentage_error: 70.3409 - val_loss: 69.0976 - val_mean_absolute_percentage_error: 69.0976
# Epoch 23/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2243 - mean_absolute_percentage_error: 70.2243 - val_loss: 69.1203 - val_mean_absolute_percentage_error: 69.1203
# Epoch 24/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2397 - mean_absolute_percentage_error: 70.2397 - val_loss: 68.9312 - val_mean_absolute_percentage_error: 68.9312
# Epoch 25/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.5235 - mean_absolute_percentage_error: 70.5235 - val_loss: 68.0881 - val_mean_absolute_percentage_error: 68.0881
# Epoch 26/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2662 - mean_absolute_percentage_error: 70.2662 - val_loss: 69.9372 - val_mean_absolute_percentage_error: 69.9372
# Epoch 27/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.3114 - mean_absolute_percentage_error: 70.3114 - val_loss: 70.1528 - val_mean_absolute_percentage_error: 70.1528
# Epoch 28/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2534 - mean_absolute_percentage_error: 70.2534 - val_loss: 69.1034 - val_mean_absolute_percentage_error: 69.1034
# Epoch 29/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2483 - mean_absolute_percentage_error: 70.2483 - val_loss: 68.8138 - val_mean_absolute_percentage_error: 68.8138
# Epoch 30/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2533 - mean_absolute_percentage_error: 70.2533 - val_loss: 69.1847 - val_mean_absolute_percentage_error: 69.1847
# Epoch 31/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2529 - mean_absolute_percentage_error: 70.2529 - val_loss: 69.2885 - val_mean_absolute_percentage_error: 69.2885
# Epoch 32/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2345 - mean_absolute_percentage_error: 70.2345 - val_loss: 68.9720 - val_mean_absolute_percentage_error: 68.9720
# Epoch 33/100
# 14/14 [==============================] - 0s 6ms/step - loss: 70.2855 - mean_absolute_percentage_error: 70.2855 - val_loss: 68.9353 - val_mean_absolute_percentage_error: 68.9353
# Epoch 34/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3182 - mean_absolute_percentage_error: 70.3182 - val_loss: 68.4690 - val_mean_absolute_percentage_error: 68.4690
# Epoch 35/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2929 - mean_absolute_percentage_error: 70.2929 - val_loss: 69.5676 - val_mean_absolute_percentage_error: 69.5676
# Epoch 36/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2570 - mean_absolute_percentage_error: 70.2570 - val_loss: 69.4367 - val_mean_absolute_percentage_error: 69.4367
# Epoch 37/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.3050 - mean_absolute_percentage_error: 70.3050 - val_loss: 68.8843 - val_mean_absolute_percentage_error: 68.8843
# Epoch 38/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2470 - mean_absolute_percentage_error: 70.2470 - val_loss: 69.2797 - val_mean_absolute_percentage_error: 69.2797
# Epoch 39/100
# 14/14 [==============================] - 0s 6ms/step - loss: 70.3192 - mean_absolute_percentage_error: 70.3192 - val_loss: 69.6540 - val_mean_absolute_percentage_error: 69.6540
# Epoch 40/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.4302 - mean_absolute_percentage_error: 70.4302 - val_loss: 68.6274 - val_mean_absolute_percentage_error: 68.6274
# Epoch 41/100
# 14/14 [==============================] - 0s 6ms/step - loss: 70.6833 - mean_absolute_percentage_error: 70.6833 - val_loss: 70.8796 - val_mean_absolute_percentage_error: 70.8796
# Epoch 42/100
# 14/14 [==============================] - 0s 6ms/step - loss: 70.3006 - mean_absolute_percentage_error: 70.3006 - val_loss: 68.7479 - val_mean_absolute_percentage_error: 68.7479
# Epoch 43/100
# 14/14 [==============================] - 0s 6ms/step - loss: 70.2894 - mean_absolute_percentage_error: 70.2894 - val_loss: 68.3939 - val_mean_absolute_percentage_error: 68.3939
# Epoch 44/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3833 - mean_absolute_percentage_error: 70.3833 - val_loss: 68.6632 - val_mean_absolute_percentage_error: 68.6632
# Epoch 45/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.4550 - mean_absolute_percentage_error: 70.4550 - val_loss: 70.0972 - val_mean_absolute_percentage_error: 70.0972
# Epoch 46/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2664 - mean_absolute_percentage_error: 70.2664 - val_loss: 69.1561 - val_mean_absolute_percentage_error: 69.1561
# Epoch 47/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.4344 - mean_absolute_percentage_error: 70.4344 - val_loss: 68.5238 - val_mean_absolute_percentage_error: 68.5238
# Epoch 48/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2418 - mean_absolute_percentage_error: 70.2418 - val_loss: 69.4717 - val_mean_absolute_percentage_error: 69.4717
# Epoch 49/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.3354 - mean_absolute_percentage_error: 70.3354 - val_loss: 69.5639 - val_mean_absolute_percentage_error: 69.5639
# Epoch 50/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.3350 - mean_absolute_percentage_error: 70.3350 - val_loss: 69.9605 - val_mean_absolute_percentage_error: 69.9605
# Epoch 51/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.3299 - mean_absolute_percentage_error: 70.3299 - val_loss: 69.7616 - val_mean_absolute_percentage_error: 69.7616
# Epoch 52/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2422 - mean_absolute_percentage_error: 70.2422 - val_loss: 69.2320 - val_mean_absolute_percentage_error: 69.2320
# Epoch 53/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.5146 - mean_absolute_percentage_error: 70.5146 - val_loss: 68.1396 - val_mean_absolute_percentage_error: 68.1396
# Epoch 54/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.3828 - mean_absolute_percentage_error: 70.3828 - val_loss: 69.4415 - val_mean_absolute_percentage_error: 69.4415
# Epoch 55/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.3092 - mean_absolute_percentage_error: 70.3092 - val_loss: 69.7187 - val_mean_absolute_percentage_error: 69.7187
# Epoch 56/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2372 - mean_absolute_percentage_error: 70.2372 - val_loss: 69.1015 - val_mean_absolute_percentage_error: 69.1015
# Epoch 57/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3058 - mean_absolute_percentage_error: 70.3058 - val_loss: 69.0955 - val_mean_absolute_percentage_error: 69.0955
# Epoch 58/100
# 14/14 [==============================] - 0s 6ms/step - loss: 70.2697 - mean_absolute_percentage_error: 70.2697 - val_loss: 68.7384 - val_mean_absolute_percentage_error: 68.7384
# Epoch 59/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3239 - mean_absolute_percentage_error: 70.3239 - val_loss: 69.0499 - val_mean_absolute_percentage_error: 69.0499
# Epoch 60/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2555 - mean_absolute_percentage_error: 70.2555 - val_loss: 69.5481 - val_mean_absolute_percentage_error: 69.5481
# Epoch 61/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2338 - mean_absolute_percentage_error: 70.2338 - val_loss: 68.9848 - val_mean_absolute_percentage_error: 68.9848
# Epoch 62/100
# 14/14 [==============================] - 0s 6ms/step - loss: 70.2812 - mean_absolute_percentage_error: 70.2812 - val_loss: 69.6291 - val_mean_absolute_percentage_error: 69.6291
# Epoch 63/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2588 - mean_absolute_percentage_error: 70.2588 - val_loss: 69.1639 - val_mean_absolute_percentage_error: 69.1639
# Epoch 64/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2487 - mean_absolute_percentage_error: 70.2487 - val_loss: 69.5290 - val_mean_absolute_percentage_error: 69.5290
# Epoch 65/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2280 - mean_absolute_percentage_error: 70.2280 - val_loss: 68.7576 - val_mean_absolute_percentage_error: 68.7576
# Epoch 66/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.3165 - mean_absolute_percentage_error: 70.3165 - val_loss: 68.3906 - val_mean_absolute_percentage_error: 68.3906
# Epoch 67/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2722 - mean_absolute_percentage_error: 70.2722 - val_loss: 69.8492 - val_mean_absolute_percentage_error: 69.8492
# Epoch 68/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.3142 - mean_absolute_percentage_error: 70.3142 - val_loss: 69.9396 - val_mean_absolute_percentage_error: 69.9396
# Epoch 69/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3409 - mean_absolute_percentage_error: 70.3409 - val_loss: 69.7305 - val_mean_absolute_percentage_error: 69.7305
# Epoch 70/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.4811 - mean_absolute_percentage_error: 70.4811 - val_loss: 70.3375 - val_mean_absolute_percentage_error: 70.3375
# Epoch 71/100
# 14/14 [==============================] - 0s 6ms/step - loss: 70.3356 - mean_absolute_percentage_error: 70.3356 - val_loss: 69.9855 - val_mean_absolute_percentage_error: 69.9855
# Epoch 72/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2738 - mean_absolute_percentage_error: 70.2738 - val_loss: 69.3500 - val_mean_absolute_percentage_error: 69.3500
# Epoch 73/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3692 - mean_absolute_percentage_error: 70.3692 - val_loss: 68.2817 - val_mean_absolute_percentage_error: 68.2817
# Epoch 74/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.4196 - mean_absolute_percentage_error: 70.4196 - val_loss: 69.2209 - val_mean_absolute_percentage_error: 69.2209
# Epoch 75/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2641 - mean_absolute_percentage_error: 70.2641 - val_loss: 69.3362 - val_mean_absolute_percentage_error: 69.3362
# Epoch 76/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.6339 - mean_absolute_percentage_error: 70.6339 - val_loss: 67.8782 - val_mean_absolute_percentage_error: 67.8782
# Epoch 77/100
# 14/14 [==============================] - 0s 6ms/step - loss: 70.3735 - mean_absolute_percentage_error: 70.3735 - val_loss: 69.2040 - val_mean_absolute_percentage_error: 69.2040
# Epoch 78/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.4177 - mean_absolute_percentage_error: 70.4177 - val_loss: 68.9076 - val_mean_absolute_percentage_error: 68.9076
# Epoch 79/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.3523 - mean_absolute_percentage_error: 70.3523 - val_loss: 69.7179 - val_mean_absolute_percentage_error: 69.7179
# Epoch 80/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2614 - mean_absolute_percentage_error: 70.2614 - val_loss: 69.4329 - val_mean_absolute_percentage_error: 69.4329
# Epoch 81/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2561 - mean_absolute_percentage_error: 70.2561 - val_loss: 69.5803 - val_mean_absolute_percentage_error: 69.5803
# Epoch 82/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.3626 - mean_absolute_percentage_error: 70.3626 - val_loss: 69.4389 - val_mean_absolute_percentage_error: 69.4389
# Epoch 83/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2300 - mean_absolute_percentage_error: 70.2300 - val_loss: 69.0423 - val_mean_absolute_percentage_error: 69.0423
# Epoch 84/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2997 - mean_absolute_percentage_error: 70.2997 - val_loss: 68.6986 - val_mean_absolute_percentage_error: 68.6986
# Epoch 85/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2492 - mean_absolute_percentage_error: 70.2492 - val_loss: 68.7502 - val_mean_absolute_percentage_error: 68.7502
# Epoch 86/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2482 - mean_absolute_percentage_error: 70.2482 - val_loss: 68.8130 - val_mean_absolute_percentage_error: 68.8130
# Epoch 87/100
# 14/14 [==============================] - 0s 6ms/step - loss: 70.2883 - mean_absolute_percentage_error: 70.2883 - val_loss: 68.5275 - val_mean_absolute_percentage_error: 68.5275
# Epoch 88/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2505 - mean_absolute_percentage_error: 70.2505 - val_loss: 69.3994 - val_mean_absolute_percentage_error: 69.3994
# Epoch 89/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.4205 - mean_absolute_percentage_error: 70.4205 - val_loss: 70.3478 - val_mean_absolute_percentage_error: 70.3478
# Epoch 90/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.7794 - mean_absolute_percentage_error: 70.7794 - val_loss: 68.0719 - val_mean_absolute_percentage_error: 68.0719
# Epoch 91/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2429 - mean_absolute_percentage_error: 70.2429 - val_loss: 69.6930 - val_mean_absolute_percentage_error: 69.6930
# Epoch 92/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.4486 - mean_absolute_percentage_error: 70.4486 - val_loss: 70.0220 - val_mean_absolute_percentage_error: 70.0220
# Epoch 93/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2615 - mean_absolute_percentage_error: 70.2615 - val_loss: 67.8991 - val_mean_absolute_percentage_error: 67.8991
# Epoch 94/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.4971 - mean_absolute_percentage_error: 70.4971 - val_loss: 67.9386 - val_mean_absolute_percentage_error: 67.9386
# Epoch 95/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.1680 - mean_absolute_percentage_error: 70.1680 - val_loss: 70.5992 - val_mean_absolute_percentage_error: 70.5992
# Epoch 96/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.4677 - mean_absolute_percentage_error: 70.4677 - val_loss: 70.4977 - val_mean_absolute_percentage_error: 70.4977
# Epoch 97/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.5151 - mean_absolute_percentage_error: 70.5151 - val_loss: 68.7818 - val_mean_absolute_percentage_error: 68.7818
# Epoch 98/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2115 - mean_absolute_percentage_error: 70.2115 - val_loss: 69.5663 - val_mean_absolute_percentage_error: 69.5663
# Epoch 99/100
# 14/14 [==============================] - 0s 6ms/step - loss: 70.2930 - mean_absolute_percentage_error: 70.2930 - val_loss: 69.4711 - val_mean_absolute_percentage_error: 69.4711
# Epoch 100/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2320 - mean_absolute_percentage_error: 70.2320 - val_loss: 69.2042 - val_mean_absolute_percentage_error: 69.2042

# %% [markdown]
# The metric used in this problem to evaluate the performance is the same we used for training the model, the mean absolute percentage error. Mean absolute percentage error is defined as $\frac{100}{n} \sum_n \frac{|\hat{y} - y|}{|y|}$ where $y$ is the ground-truth, $\hat{y}$ is the estimation of the model and `n` the number of elements in the set we are evaluating.

# %%
def evaluate_model(model, num, summary=1):
    print("Model %s:" % str(num))
    if summary:
        model.summary()

    opt = Adam(learning_rate=1e-3, decay=1e-3 / 200)
    model.compile(loss="mean_absolute_percentage_error", optimizer=opt, metrics=['mean_absolute_percentage_error'])

    # train the model
    # print("[INFO] training model...")
    history = model.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=100, batch_size=32, verbose=False)

    prices_predicted = model.predict(X_val).flatten()
    diff = ((prices_predicted - Y_val) / Y_val) * 100
    error_mean = np.mean(np.abs(diff))

    print("Predicting house prices - Estimation Error: {:.2f}%".format(error_mean))

    plt.plot(history.history['loss'], label="train")
    plt.plot(history.history['val_loss'], label="val")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.ylim(0,100)
    plt.title("Model %s: Loss over epoch" % str(num))
    plt.legend()
    plt.show()

# %% [markdown]
# **Report**:
#
#
# *   Propose a CNN architecture that has an estimation error in the validation set below 75%.
# *   Present a figure showing the training and validation loss vs the number of training epochs for different architectural design choices. Discuss the gap between the training and validation loss depending on the proposed architecture.
# *   Report a table with results when using any of the other images from the house (kitchen, bedroom, and bathroom).

# %% [markdown]
# #### Loss over epoch

# %%
# Model 1: simple
m1 = Sequential()
m1.add(Conv2D(32, (3,3), padding='same', input_shape=X_train.shape[1:]))
m1.add(Activation('relu'))
m1.add(MaxPooling2D(pool_size=(2,2)))
m1.add(Flatten())
m1.add(Dense(64, activation='relu'))
m1.add(Dense(1))

# Model 2: multiple conv layers
m2 = Sequential()
m2.add(Conv2D(16, (3,3), padding='same', input_shape=X_train.shape[1:]))
m2.add(Activation('relu'))
m2.add(MaxPooling2D(pool_size=(2,2)))
m2.add(Conv2D(32, (3,3), padding='same'))
m2.add(Activation('relu'))
m2.add(MaxPooling2D(pool_size=(2,2)))
m2.add(Conv2D(64, (3,3), padding='same'))
m2.add(Activation('relu'))
m2.add(MaxPooling2D(pool_size=(2,2)))
m2.add(Flatten())
m2.add(Dense(64, activation='relu'))
m2.add(Dense(1))

# Model 3: multiple fc layers 
m3 = Sequential()
m3.add(Conv2D(16, (3,3), padding='same', input_shape=X_train.shape[1:]))
m3.add(Activation('relu'))
m3.add(MaxPooling2D(pool_size=(2,2)))
m3.add(Conv2D(32, (3,3), padding='same'))
m3.add(Activation('relu'))
m3.add(MaxPooling2D(pool_size=(2,2)))
m3.add(Flatten())
m3.add(Dense(16, activation='relu'))
m3.add(Dense(64, activation='relu'))
m3.add(Dense(128, activation='relu'))
m3.add(Dense(1))

# Model 4: activation function
m4 = Sequential()
m4.add(Conv2D(16, (3,3), padding='same', input_shape=X_train.shape[1:]))
m4.add(Activation('tanh'))
m4.add(MaxPooling2D(pool_size=(2,2)))
m4.add(Conv2D(32, (3,3), padding='same'))
m4.add(Activation('tanh'))
m4.add(MaxPooling2D(pool_size=(2,2)))
m4.add(Flatten())
m4.add(Dense(64, activation='tanh'))
m4.add(Dense(1))

evaluate_model(m1, 1)
evaluate_model(m2, 2)
evaluate_model(m3, 3)
evaluate_model(m4, 4)
# Out:
# Model 1:
# Model: "sequential_101"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_191 (Conv2D)         (None, 64, 64, 32)        896
#
#  activation_204 (Activation)  (None, 64, 64, 32)       0
#
#  max_pooling2d_165 (MaxPooli  (None, 32, 32, 32)       0
#  ng2D)
#
#  flatten_98 (Flatten)        (None, 32768)             0
#
#  dense_250 (Dense)           (None, 64)                2097216
#
#  dense_251 (Dense)           (None, 1)                 65
#
# =================================================================
# Total params: 2,098,177
# Trainable params: 2,098,177
# Non-trainable params: 0
# _________________________________________________________________
# 4/4 [==============================] - 0s 3ms/step
# Predicting house prices - Estimation Error: 76.60%
# Model 2:
# Model: "sequential_102"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_192 (Conv2D)         (None, 64, 64, 16)        448
#
#  activation_205 (Activation)  (None, 64, 64, 16)       0
#
#  max_pooling2d_166 (MaxPooli  (None, 32, 32, 16)       0
#  ng2D)
#
#  conv2d_193 (Conv2D)         (None, 32, 32, 32)        4640
#
#  activation_206 (Activation)  (None, 32, 32, 32)       0
#
#  max_pooling2d_167 (MaxPooli  (None, 16, 16, 32)       0
#  ng2D)
#
#  conv2d_194 (Conv2D)         (None, 16, 16, 64)        18496
#
#  activation_207 (Activation)  (None, 16, 16, 64)       0
#
#  max_pooling2d_168 (MaxPooli  (None, 8, 8, 64)         0
#  ng2D)
#
#  flatten_99 (Flatten)        (None, 4096)              0
#
#  dense_252 (Dense)           (None, 64)                262208
#
#  dense_253 (Dense)           (None, 1)                 65
#
# =================================================================
# Total params: 285,857
# Trainable params: 285,857
# Non-trainable params: 0
# _________________________________________________________________
# 4/4 [==============================] - 0s 3ms/step
# Predicting house prices - Estimation Error: 56.29%
# Model 3:
# Model: "sequential_103"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_195 (Conv2D)         (None, 64, 64, 16)        448
#
#  activation_208 (Activation)  (None, 64, 64, 16)       0
#
#  max_pooling2d_169 (MaxPooli  (None, 32, 32, 16)       0
#  ng2D)
#
#  conv2d_196 (Conv2D)         (None, 32, 32, 32)        4640
#
#  activation_209 (Activation)  (None, 32, 32, 32)       0
#
#  max_pooling2d_170 (MaxPooli  (None, 16, 16, 32)       0
#  ng2D)
#
#  flatten_100 (Flatten)       (None, 8192)              0
#
#  dense_254 (Dense)           (None, 16)                131088
#
#  dense_255 (Dense)           (None, 64)                1088
#
#  dense_256 (Dense)           (None, 128)               8320
#
#  dense_257 (Dense)           (None, 1)                 129
#
# =================================================================
# Total params: 145,713
# Trainable params: 145,713
# Non-trainable params: 0
# _________________________________________________________________
# 4/4 [==============================] - 0s 4ms/step
# Predicting house prices - Estimation Error: 82.58%
# Model 4:
# Model: "sequential_104"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_197 (Conv2D)         (None, 64, 64, 16)        448
#
#  activation_210 (Activation)  (None, 64, 64, 16)       0
#
#  max_pooling2d_171 (MaxPooli  (None, 32, 32, 16)       0
#  ng2D)
#
#  conv2d_198 (Conv2D)         (None, 32, 32, 32)        4640
#
#  activation_211 (Activation)  (None, 32, 32, 32)       0
#
#  max_pooling2d_172 (MaxPooli  (None, 16, 16, 32)       0
#  ng2D)
#
#  flatten_101 (Flatten)       (None, 8192)              0
#
#  dense_258 (Dense)           (None, 64)                524352
#
#  dense_259 (Dense)           (None, 1)                 65
#
# =================================================================
# Total params: 529,505
# Trainable params: 529,505
# Non-trainable params: 0
# _________________________________________________________________
# 4/4 [==============================] - 0s 4ms/step
# Predicting house prices - Estimation Error: 58.91%

# %% [markdown]
# #### Using Other Images

# %%
def make_regression_model():
    model = Sequential()
    model.add(Conv2D(16, (3,3), padding='same', input_shape=X_train.shape[1:]))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Conv2D(32, (3,3), padding='same'))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Conv2D(64, (3,3), padding='same'))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Flatten())
    model.add(Dense(64, activation='relu'))
    model.add(Dense(1))
    return model

# %%
images, labels = import_images('kitchen')
X_train, X_val, Y_train, Y_val = prepare_dataset(images, labels)
model_kitchen = make_regression_model()
evaluate_model(model_kitchen, "(kitchen)", summary=0)
# Out:
# We have selected kitchen images. You can switch to the kitchen, frontal, bedroom or bathroom images by changing house_section variable.
# X_train image shape: (428, 64, 64, 3)
# X_val image shape: (106, 64, 64, 3)
# Y_train labels shape: (428,)
# Y_val labels shape: (106,)
# Model (kitchen):
# 4/4 [==============================] - 0s 4ms/step
# Predicting house prices - Estimation Error: 54.09%

# %%
images, labels = import_images('bedroom')
X_train, X_val, Y_train, Y_val = prepare_dataset(images, labels)
model_kitchen = make_regression_model()
evaluate_model(model_kitchen, "(bedroom)", summary=0)
# Out:
# We have selected bedroom images. You can switch to the kitchen, frontal, bedroom or bathroom images by changing house_section variable.
# X_train image shape: (428, 64, 64, 3)
# X_val image shape: (106, 64, 64, 3)
# Y_train labels shape: (428,)
# Y_val labels shape: (106,)
# Model (bedroom):
# 4/4 [==============================] - 0s 4ms/step
# Predicting house prices - Estimation Error: 57.39%

# %%
images, labels = import_images('bathroom')
X_train, X_val, Y_train, Y_val = prepare_dataset(images, labels)
model_kitchen = make_regression_model()
evaluate_model(model_kitchen, "(bathroom)", summary=0)
# Out:
# We have selected bathroom images. You can switch to the kitchen, frontal, bedroom or bathroom images by changing house_section variable.
# X_train image shape: (428, 64, 64, 3)
# X_val image shape: (106, 64, 64, 3)
# Y_train labels shape: (428,)
# Y_val labels shape: (106,)
# Model (bathroom):
# 4/4 [==============================] - 0s 4ms/step
# Predicting house prices - Estimation Error: 69.92%
